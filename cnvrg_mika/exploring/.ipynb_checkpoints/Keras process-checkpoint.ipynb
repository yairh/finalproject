# %% [markdown]
# ## DATA AUGMENTATION
# - flip imag
# - rotation
# - zooming the image
# - cropping the
# - varying the color

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot
import numpy as np
from scipy import misc, ndimage
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
import os
import cv2
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
def plots(img, figsize=(12,6), rows=1, interp=False, titles=None):
    if type(img[0]) is np.ndarray:
        img = np.array(img).astype(np.uint8)
        if (img.shape[-1] != 3):
            img = img.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = len(img)//rows if len(img) % 2 == 0 else len(img)//rows +1
    for _ in range(len(img)):
        sp = f.add_subplot(rows, cols, _+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[_], fontsize=16)
        plt.imshow(img[_][:,:,0], interpolation=None if interp else 'none')

# %%
gen = ImageDataGenerator(rotation_range=10, width_shift_range=0.1,
                        height_shift_range=0.1, shear_range=0.15,
                        zoom_range=0.1, channel_shift_range=10,
                        horizontal_flip=True)

# %%
image_path = "../imgs/00003969_000.png"
# image_path = "gal.jpeg"

# %%
f = plt.figure(figsize=(7,7))
image = np.expand_dims(ndimage.imread(image_path),0 )
plt.imshow(image[0], cmap='gray')
# Out:
# C:\Users\micka\Anaconda3\envs\tensorflow-sessions\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.

# %%
image.shape
# Out:
# (1, 1024, 1024)

# %%
im2 = np.expand_dims(image, -1)
im2.shape
# Out:
# (1, 1024, 1024, 1)

# %%
aug_iter = gen.flow(im2)

# %%
aug_iter[0].shape
# Out:
# (1, 1024, 1024, 1)

# %%
aug_images = [next(aug_iter)[0].astype(np.uint8) for i in range(10)]

# %%
for i in aug_images:
    plt.figure(figsize=(15,5))
    plt.imshow(i[:][:,:,0], cmap='gray')

# %%
DATADIR = r"C:\Users\micka\Mike\Coding\ITC Code\Projet DS\mika_local\imgs\binary\train"
CATEGORIES = ['Finding', 'No Finding']

for category in CATEGORIES:
    path = os.path.join(DATADIR, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        print(img_array.shape)
        plt.figure(figsize=(15,10))
        plt.imshow(img_array, cmap='gray')
        plt.show()
        break
    break
# Out:
# (1024, 1024)

# %%
IMG_SIZE = 100
plt.figure(figsize=(15,10))
new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(new_array, cmap='gray')
