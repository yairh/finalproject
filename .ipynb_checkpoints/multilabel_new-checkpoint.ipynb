# %%
from class_dataset import ChestDataset
import pandas as pd
from keras.callbacks import TensorBoard, ModelCheckpoint,ReduceLROnPlateau
from keras.layers import Dense, Activation, Conv2D, MaxPool2D, Flatten, BatchNormalization, Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras import applications
from keras.applications import DenseNet121
from keras import models
from keras.utils.np_utils import to_categorical
from keras import backend as K
from tensorflow.python.client import device_lib
import numpy as np
from sklearn.utils import class_weight
import matplotlib
# matplotlib.use('Agg')
import matplotlib.pyplot as plt
from keras.optimizers import Adam
import os
from glob import glob
import seaborn as sns
from itertools import chain
from collections import Counter
from sklearn.metrics import roc_curve,auc, classification_report, accuracy_score, precision_recall_curve
from sklearn.preprocessing import MultiLabelBinarizer

# %%
print(device_lib.list_local_devices())
print(K.tensorflow_backend._get_available_gpus())
# os.system('sudo chown -R ds:ds /data')
# os.mkdir('output')
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3771261025206421671
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 4799144568894990047
# physical_device_desc: "device: XLA_CPU device"
# ]
# []

# %%
# CHOOSE now your model name 
model_name = 'densechest_multilabel'

csvfile = 'data_kaggle/Data_Entry_2017.csv'
df = pd.read_csv(csvfile)

# data_dir = '/data/xray_chest_final/'
data_dir = '../image/images/'
ChestDataset(data_dir,df).reset_folder()

df = ChestDataset(data_dir,df).reader
df = df[df.exists == True]

# %%
df['labels'] = df['Finding Labels'].apply(lambda x: '' if x=='No Finding' else x.split('|'))
binarizer = MultiLabelBinarizer()
binarizer.fit(df.labels)
df['target'] = list(binarizer.transform(df.labels))

idx_to_drop = [idx for idx in df[df['Finding Labels'] == 'No Finding'].index.values[::2]]
df = df.drop(idx_to_drop,axis=0)

# %%
all_labels = list(chain.from_iterable(list(
    df[~(df['Finding Labels'] == 'No Finding')]['Finding Labels'].apply(lambda x: x.split('|')))))
class_weights = Counter(all_labels)
for label in class_weights.keys():
    class_weights[label] = max(class_weights.values())/class_weights[label]
class_weights = {list(binarizer.classes_).index(k):v for k,v in class_weights.items()}
class_indices = {list(binarizer.classes_)[k]: k for k in class_weights.keys()}

# %%
dataset = ChestDataset(data_dir,df)

df['path'] = dataset.image_path

train_list = [el[len(data_dir):] for i,el in enumerate(dataset.image_path) if not i%5 == 0]
test_list = [el[len(data_dir):] for i,el in enumerate(dataset.image_path) if i%5 == 0]

# %%
with open('output/{}_train_list.txt'.format(model_name), 'w') as f:
    for item in train_list:
        f.write("%s\n" % item)

with open('output/{}_test_list.txt'.format(model_name), 'w') as f:
    for item in test_list:
        f.write("%s\n" % item)

# %%
# ADD YOUR MODEL
im_width,im_heigth = 256,256
densenet = DenseNet121(weights='imagenet', include_top=False,input_shape = (im_width,im_heigth,3))

# # Freeze some layers
# for layer in densenet.layers[:100]:
#     layer.trainable = False
    
# Create the model
model = models.Sequential()

model.add(densenet)

# Add new layers
model.add(Flatten())
# model.add(Dense(72))
# model.add(BatchNormalization())
model.add(Activation('relu'))
# model.add(Dropout(0.5))
model.add(Dense(14, activation='sigmoid'))

# Show a summary of the model. Check the number of trainable parameters
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Model)          (None, 8, 8, 1024)        7037504
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 65536)             0
# _________________________________________________________________
# activation_1 (Activation)    (None, 65536)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 14)                917518
# =================================================================
# Total params: 7,955,022
# Trainable params: 7,871,374
# Non-trainable params: 83,648
# _________________________________________________________________

# %%
def flow_from_dataframe(img_data_gen, in_df, path_col, y_col, class_indices, **dflow_args):
    base_dir = os.path.dirname(in_df[path_col].values[0])
    print('## Ignore next message from keras, values are replaced anyways')
    df_gen = img_data_gen.flow_from_directory(base_dir, 
                                     class_mode = 'sparse',
                                    **dflow_args)
    df_gen.filenames = in_df[path_col].values
    df_gen.classes = np.stack(in_df[y_col].values)
    df_gen.samples = in_df.shape[0]
    df_gen.n = in_df.shape[0]
    df_gen._set_index_array()
    df_gen.directory = '' # since we have the full path
    df_gen.classes_indices = class_indices
    print('Reinserting dataframe: {} images'.format(in_df.shape[0]))
    return df_gen

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   samplewise_center=True, 
                                   samplewise_std_normalization=True,
                                   horizontal_flip = True,
                                   vertical_flip = False, 
                                   height_shift_range= 0.05, 
                                   width_shift_range=0.1, 
                                   rotation_range=5,
                                   shear_range = 0.1,
                                   fill_mode = 'reflect',
                                   zoom_range=0.15)

validation_datagen = ImageDataGenerator(rescale=1./255)

df_train = df[df['Image Index'].isin(train_list)]
df_test = df[df['Image Index'].isin(test_list)]

# Change the batchsize according to your system RAM
train_batchsize = 16
val_batchsize = 16

train_generator = flow_from_dataframe(train_datagen, df_train, 
                             path_col = 'path',
                            y_col = 'target',
                            class_indices = class_indices,
                            target_size = (im_width,im_heigth),
                             color_mode = 'rgb',
                            batch_size = train_batchsize)

validation_generator = flow_from_dataframe(validation_datagen, df_test, 
                             path_col = 'path',
                            y_col = 'target',
                            class_indices = class_indices,
                            target_size = (im_width,im_heigth),
                             color_mode = 'rgb',
                            batch_size = val_batchsize)
# Out:
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 1 classes.
# Reinserting dataframe: 22714 images
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 1 classes.
# Reinserting dataframe: 5679 images

# %%
# train_generator = train_datagen.flow_from_dataframe(df_train,
#                                                    x_col='path',
#                                                    y_col='disease_vec',
#                                                    target_size=(im_width,im_heigth),
#                                                    color_mode='rgb',
#                                                    class_mode='other',
#                                                    batch_size=train_batchsize)

# validation_generator = validation_datagen.flow_from_dataframe(df_test,
#                                                    x_col='path',
#                                                    y_col='disease_vec',
#                                                    target_size=(im_width,im_heigth),
#                                                    color_mode='rgb',
#                                                    class_mode='other',
#                                                    batch_size=val_batchsize)

# %%
# Compile the model
optimizer = Adam(lr=0.01)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['categorical_accuracy'])

# tensorboard = TensorBoard(log_dir='output/logs', histogram_freq=0,
#                           write_graph=True, write_images=False)
# filepath = "output/checkpoint_{}.hdf5".format(model_name)
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_acc', 
                             verbose=1,save_best_only=True,mode='max')

lr_sc = ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=1,verbose=1)

# Train the model
history = model.fit_generator(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=5,
    class_weight = class_weights,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    verbose=1,
    callbacks=[checkpoint,lr_sc],
    use_multiprocessing=True)
# Out:
# Epoch 1/5
# 2271/2272 [============================>.] - ETA: 0s - loss: 1.5290 - categorical_accuracy: 0.6752Epoch 1/5
# 2272/2272 [==============================] - 1177s 518ms/step - loss: 1.5285 - categorical_accuracy: 0.6753 - val_loss: 0.7150 - val_categorical_accuracy: 0.6783
# Epoch 2/5
# /opt/ds3/lib/python3.5/site-packages/keras/callbacks.py:435: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# 2272/2272 [==============================] - 1096s 482ms/step - loss: 1.5279 - categorical_accuracy: 0.6757 - val_loss: 0.7150 - val_categorical_accuracy: 0.6783
# Epoch 3/5
# 2271/2272 [============================>.] - ETA: 0s - loss: 1.5287 - categorical_accuracy: 0.6756
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-45:
# Traceback (most recent call last):
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-187-1582c25c6479> in <module>()
#      18     verbose=1,
#      19     callbacks=[checkpoint],
# ---> 20     use_multiprocessing=True)
#
# /opt/ds3/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /opt/ds3/lib/python3.5/site-packages/keras/models.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1313                                         use_multiprocessing=use_multiprocessing,
#    1314                                         shuffle=shuffle,
# -> 1315                                         initial_epoch=initial_epoch)
#    1316
#    1317     @interfaces.legacy_generator_methods_support
#
# /opt/ds3/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /opt/ds3/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2248                                 workers=workers,
#    2249                                 use_multiprocessing=use_multiprocessing,
# -> 2250                                 max_queue_size=max_queue_size)
#    2251                         else:
#    2252                             # No need for try/except because
#
# /opt/ds3/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /opt/ds3/lib/python3.5/site-packages/keras/engine/training.py in evaluate_generator(self, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#    2397                                      'or (x, y). Found: ' +
#    2398                                      str(generator_output))
# -> 2399                 outs = self.test_on_batch(x, y, sample_weight=sample_weight)
#    2400                 if not isinstance(outs, list):
#    2401                     outs = [outs]
#
# /opt/ds3/lib/python3.5/site-packages/keras/engine/training.py in test_on_batch(self, x, y, sample_weight)
#    1922             ins = x + y + sample_weights
#    1923         self._make_test_function()
# -> 1924         outputs = self.test_function(ins)
#    1925         if len(outputs) == 1:
#    1926             return outputs[0]
#
# /opt/ds3/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2478             feed_dict[tensor] = value
#    2479         fetches = self.outputs + [self.updates_op] + self.fetches
# -> 2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
#    2482                               **self.session_kwargs)
#
# /opt/ds3/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     182     if not _MANUAL_VAR_INIT:
#     183         with session.graph.as_default():
# --> 184             variables = tf.global_variables()
#     185             candidate_vars = []
#     186             for v in variables:
#
# /opt/ds3/lib/python3.5/site-packages/tensorflow/python/ops/variables.py in global_variables(scope)
#    1411     A list of `Variable` objects.
#    1412   """
# -> 1413   return ops.get_collection(ops.GraphKeys.GLOBAL_VARIABLES, scope)
#    1414
#    1415
#
# /opt/ds3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in get_collection(key, scope)
#    5879   @end_compatibility
#    5880   """
# -> 5881   return get_default_graph().get_collection(key, scope)
#    5882
#    5883
#
# /opt/ds3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in get_collection(self, name, scope)
#    3941         return []
#    3942       if scope is None:
# -> 3943         return list(collection)
#    3944       else:
#    3945         c = []
#
# KeyboardInterrupt:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/ds3/lib/python3.5/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/opt/ds3/lib/python3.5/site-packages/keras/preprocessing/image.py", line 1034, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#   File "/opt/ds3/lib/python3.5/site-packages/keras/preprocessing/image.py", line 1438, in _get_batches_of_transformed_samples
#     interpolation=self.interpolation)
#   File "/opt/ds3/lib/python3.5/site-packages/keras/preprocessing/image.py", line 393, in load_img
#     img = img.convert('RGB')
#   File "/opt/ds3/lib/python3.5/site-packages/PIL/Image.py", line 879, in convert
#     self.load()
#   File "/opt/ds3/lib/python3.5/site-packages/PIL/ImageFile.py", line 231, in load
#     n, err_code = decoder.decode(b)
# KeyboardInterrupt

# %%
# serialize model to JSON
model_json = model.to_json()
with open("output/{}.json".format(model_name), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("output/{}.h5".format(model_name))
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
fig = plt.figure(figsize=(12,6))
plt.subplot(121)
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig.savefig('output/history_{}.png'.format(model_name))

# %%
prediction = model.predict_generator(validation_generator,
                                     steps=len(validation_generator),
                                     pickle_safe=True,
                                     verbose=1)
preds = np.zeros_like(prediction)
preds[np.arange(len(prediction)), prediction.argmax(1)] = 1
# Out:
# /opt/ds3/lib/python3.5/site-packages/ipykernel_launcher.py:4: UserWarning: Update your `predict_generator` call to the Keras 2 API: `predict_generator(<keras.pre..., steps=568, use_multiprocessing=True, verbose=1)`
#   after removing the cwd from sys.path.
# 568/568 [==============================] - 108s 190ms/step

# %%
y_true = validation_generator.classes
pred_cat = [labels[np.argmax(el)] for i,el in enumerate(preds)]

report = classification_report(y_true,preds)
np.save('output/report_{}.npy'.format(model_name),report)
print(report)
print('Accuracy score: ',accuracy_score(validation_generator.classes,preds))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00       525
#           1       0.00      0.00      0.00       190
#           2       0.00      0.00      0.00       209
#           3       0.00      0.00      0.00        67
#           4       0.00      0.00      0.00       511
#           5       0.00      0.00      0.00        91
#           6       0.00      0.00      0.00       128
#           7       0.00      0.00      0.00        13
#           8       0.00      0.00      0.00       870
#           9       0.00      0.00      0.00       191
#          10       0.59      1.00      0.74      3327
#          11       0.00      0.00      0.00       276
#          12       0.00      0.00      0.00       170
#          13       0.00      0.00      0.00        67
#          14       0.00      0.00      0.00       219
#
# avg / total       0.28      0.49      0.36      6854
#
# Accuracy score:  0.5858425779186477
# /opt/ds3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
score = model.evaluate_generator(validation_generator,
                                 steps=len(validation_generator),
                                 pickle_safe=True)
print('Accuracy Keras: ', score[1])
# Out:
# /opt/ds3/lib/python3.5/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `evaluate_generator` call to the Keras 2 API: `evaluate_generator(<keras.pre..., steps=568, use_multiprocessing=True)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# Accuracy Keras:  0.5858425834498411

# %%
# Auc scores
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(len(labels)):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], prediction[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fig = plt.figure(figsize=(15,10))
for i in range(len(labels)):
    plt.plot(fpr[i], tpr[i],
             label='ROC curve for {0} (area = {1:0.2f})'
             ''.format(labels[i], roc_auc[i]))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.legend(loc="lower right")
plt.show()
fig.savefig('output/roc_curve_{}.png'.format(model_name))

print('End Of Training')
# Out:
# End Of Training

# %%
precision = dict()
recall = dict()
for i in range(len(labels)):
    precision[i], recall[i], _ = precision_recall_curve(y_true[:, i], prediction[:, i])

fig = plt.figure(figsize=(15,10))
for i in range(len(labels)):
    plt.plot(recall[i], precision[i],
             label='PR curve for {0}'
             ''.format(labels[i]))
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('PR curve')
plt.legend(loc="lower right")
plt.show()
